# %% [markdown]
# <img src="logo completo.png" width="1200" height="400">

# %% [markdown]
# 1. Consiga el conjunto de datos iris.csv. En el repositorio de Aprendizaje Profundo encuentra alguna versión.
# 2. Escriba una clase iterable que tenga la siguiente funcionalidad
#     1. Al instanciar un objeto, lee el archivo de datos y lo coloca en un dataframe interno en la clase.
#     2. Cada vez que se le pidan datos, debe regresar los dos siguientes datos.
#     3. Entregue un error si los datos se han agotado

# %%
import pandas as pd

import pandas as pd

class IrisDatasetIterator:
    def __init__(self, file_path):
        self.dataframe = pd.read_csv(file_path)
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index >= len(self.dataframe):
            raise StopIteration("No hay más datos disponibles.")
        else:
            data = self.dataframe.iloc[self.index:self.index+2]
            self.index += 2
            return data

# Instanciar la clase iterable con el archivo iris.csv
dataset_iterator = IrisDatasetIterator('G:/Mi unidad/2023-1/Inteligencia Artificial/iris.csv')

# Iterar y obtener los dos siguientes datos hasta que se agoten
try:
    while True:
        data = next(dataset_iterator)
        print("Datos obtenidos:")
        print(data)
        print()
except StopIteration as e:
    print(str(e))
# Out:
# Datos obtenidos:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
#
# Datos obtenidos:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
#
# Datos obtenidos:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
#
# Datos obtenidos:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
#
# Datos obtenidos:
#    sepal.length  sepal.width  petal.length  petal.width variety
# ...

# %%
# Instanciar la clase iterable con el archivo iris.csv
dataset_iterator = IrisDatasetIterator('ruta/iris.csv')

# Iterar y obtener los dos siguientes datos hasta que se agoten
try:
    while True:
        data = next(dataset_iterator)
        print("Datos obtenidos:")
        print(data)
        print()
except StopIteration as e:
    print(str(e))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3516\1173513443.py in <module>
#       1 # Instanciar la clase iterable con el archivo iris.csv
# ----> 2 dataset_iterator = IrisDatasetIterator('ruta/iris.csv')
#       3
#       4 # Iterar y obtener los dos siguientes datos hasta que se agoten
#       5 try:
#
# ~\AppData\Local\Temp\ipykernel_3516\4218110927.py in __init__(self, file_path)
#       5 class IrisDatasetIterator:
#       6     def __init__(self, file_path):
# ----> 7         self.dataframe = pd.read_csv(file_path)
#       8         self.index = 0
#       9
#
# c:\Users\jard1\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
