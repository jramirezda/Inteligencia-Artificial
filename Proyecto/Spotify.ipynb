# %% [markdown]
# <center>
# <h1> Sistema de Recomendación de Spotify
# <h2> Inteligencia Artificial
# <h2> 2023 - 1
# </center>
#
# *Integrantes:*
# - Jhon Alejandro Ramírez jramirezda@unal.edu.co
# - Gerardo Sebastian Gil Sanchez ggil@unal.edu.co
# - Nicolas Enrique Rodriguez Jurado	nerodriguezju@unal.edu.co
# > Este proyecto fue programado con la versión de <u>Python 3.10.11</u>
# > Recomendamos visualización y ejecución en <i>Jupyter Notebook

# %% [markdown]
# Los sistemas de recomendación desempeñan un papel fundamental en ayudarnos a navegar y descubrir contenido relevante. Un sistema de recomendación es una herramienta que utiliza algoritmos y técnicas de inteligencia artificial para analizar los datos de los usuarios y proporcionar sugerencias personalizadas sobre productos, servicios, contenido o cualquier otro elemento de interés. El objetivo principal de un sistema de recomendación es facilitar la toma de decisiones y mejorar la experiencia del usuario al ofrecer opciones adaptadas a sus preferencias y necesidades específicas.
# Estos sistemas se utilizan ampliamente en plataformas en línea, como tiendas virtuales, servicios de streaming, redes sociales y más, con el fin de ofrecer una experiencia personalizada y enriquecedora para los usuarios. Al analizar el comportamiento pasado y las interacciones de los usuarios, los sistemas de recomendación pueden predecir y sugerir elementos que se ajusten a sus gustos individuales, fomentando la exploración, la satisfacción del usuario y, en última instancia, generando un impacto positivo tanto para los usuarios como para los proveedores de contenido o servicios.
#
# **Procedimiento**
# Para realizar el Sistema de Recomendación seguimos los siguientes pasos:
# **1. Recolección de datos:** Hacer la conexión con la API, mirar que tipo de información no provee y qué estructura tiene esta información.
# **2. Organización de la información:** Guardar y organizar la información que vamos a necesitar para nuestro modelo.
# **3. Aplicación el modelo:** Aplicar el método de _Similitud de Cosenos_ para buscar nuevas canciones para el Usuario.
# **4. Evaluación del modelo:** Usar _métricas de precisión_ para comprobar la eficacia de nuestro proyecto.
# ## 1. Recolección de los datos
# A través de la API de Spotify, en principio la API nos muestra información asociada a la cuenta personal, por ejemplo, artistas, albums y pistas. Para esto hay que acceder a tu cuenta de *Spotify* desde la página de desarrollador <u>*developer.spotify.com*</u>, ya está dentro de la app es necesario hacer procesos que omitiremos en este documento.
#
# Para empezar, es necesario instalar ***spotipy*** para cargar las librerías necesariar para hacer la conexión con la API de Spotify:
# * ```pip install spotipy ```
# * ```- python3 -m pip install spotipy``` (en caso de que no te funcione la primera)

# %%
# !pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spotipy in c:\users\gsgil\appdata\roaming\python\python310\site-packages (2.23.0)
# Requirement already satisfied: six>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\gsgil\appdata\roaming\python\python310\site-packages (from spotipy) (4.5.5)
# Requirement already satisfied: urllib3>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (1.26.14)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\gsgil\appdata\roaming\python\python310\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)

# %%
import spotipy
import inspect
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %% [markdown]
# A continuación guardaremos las claves que nos provee Spotify para conectarnos por medio de la API.

# %%
cid = "70c4eff7ab204aeaaa1ee54e6304f766" # Client ID
secret = "55944900bfbc479283e1e4f88223d854" # Client Secret ID
username = "Sebastian Gil Sanchez" # Nombre de usuario 
redirect_uri = "http://localhost:8080" # URI

# %%
# PRUEBA DE OTRO USUARIO
#username = "Angelo Aguilera Avila"
#username = "jramirezda
## HAY QUE IMPLEMENTAR FRONT PARA REDIRIGIR AL USUARIO REAL A SPOTIFY Y QUE INGRESE CON LA INFORMACIÓN DE ELLOS

# %% [markdown]
# Para poder conectarnos con Spotify vamos a crear una clase que se conecta con la clase que Spotify ya tiene, para esto necesitarmos definir unos privilegios que son necesarios para acceder a cierta información de la cuenta.

# %%
# Establecer conexión
scope = 'user-top-read' # Permiso que mira Spotify para dejarnos usar la funciones
token = util.prompt_for_user_token(username,scope,cid,secret,redirect_uri) # Token para crear el objeto que hace la conexión
sp = spotipy.Spotify(auth=token) # Objeto que nos permitira acceder a la info de Spotify

# %% [markdown]
# ### Analizando la información de Spotify
# Ahora vamos a ver que tipo de información nos da Spotify:
# * ``` sp.current_user_top_tracks```
# * ``` sp.user_current_followed_artists```
# * ``` sp.current_user_playlist```
# * ``` sp.current_user_recently_played```
# * ``` sp.current_user_top_artist```
# * otros...

# %%
informacion_clase = inspect.getmembers(sp)

# Imprimir información sobre la clase
for nombre, valor in informacion_clase:
    print(f"Nombre: {nombre}")
    print(f"Valor: {valor}")
    print("----------------------------------")
# Out:
# Nombre: __class__
# Valor: <class 'spotipy.client.Spotify'>
# ----------------------------------
# Nombre: __del__
# Valor: <bound method Spotify.__del__ of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: __delattr__
# Valor: <method-wrapper '__delattr__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __dict__
# Valor: {'prefix': 'https://api.spotify.com/v1/', '_auth': 'BQCJxJiFrmzElCWtmUSUY3H-fCDyt84D4mHesXqSRO1J8UB1o9-_ngC5LX1gd7OpZ39UPHDeDrpUcUAMiziE0I74cuqDGSxfPFrxfW8NXvhtVC67wy5oN3enEVrfM5g2hLB9kfipIOHhTVvBf5R8z1WPwjyDvYH0OsWbGmTHJ6rBmXa8rwCu4pfuyRA', 'client_credentials_manager': None, 'oauth_manager': None, '_auth_manager': None, 'proxies': None, 'requests_timeout': 5, 'status_forcelist': (429, 500, 502, 503, 504), 'backoff_factor': 0.3, 'retries': 3, 'status_retries': 3, 'language': None, '_session': <requests.sessions.Session object at 0x0000024EE7452A10>}
# ----------------------------------
# Nombre: __dir__
# Valor: <built-in method __dir__ of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __doc__
# Valor:
#         Example usage::
#
#             import spotipy
#
#             urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'
#             sp = spotipy.Spotify()
#
#             artist = sp.artist(urn)
#             print(artist)
#
#             user = sp.user('plamere')
#             print(user)
#
# ----------------------------------
# Nombre: __eq__
# Valor: <method-wrapper '__eq__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __format__
# Valor: <built-in method __format__ of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __ge__
# Valor: <method-wrapper '__ge__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __getattribute__
# Valor: <method-wrapper '__getattribute__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __gt__
# Valor: <method-wrapper '__gt__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __hash__
# Valor: <method-wrapper '__hash__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __init__
# Valor: <bound method Spotify.__init__ of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: __init_subclass__
# Valor: <built-in method __init_subclass__ of type object at 0x0000024EDC32FBD0>
# ----------------------------------
# Nombre: __le__
# Valor: <method-wrapper '__le__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __lt__
# Valor: <method-wrapper '__lt__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __module__
# Valor: spotipy.client
# ----------------------------------
# Nombre: __ne__
# Valor: <method-wrapper '__ne__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __new__
# Valor: <built-in method __new__ of type object at 0x00007FFEDF8BABB0>
# ----------------------------------
# Nombre: __reduce__
# Valor: <built-in method __reduce__ of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __reduce_ex__
# Valor: <built-in method __reduce_ex__ of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __repr__
# Valor: <method-wrapper '__repr__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __setattr__
# Valor: <method-wrapper '__setattr__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __sizeof__
# Valor: <built-in method __sizeof__ of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __str__
# Valor: <method-wrapper '__str__' of Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __subclasshook__
# Valor: <built-in method __subclasshook__ of type object at 0x0000024EDC32FBD0>
# ----------------------------------
# Nombre: __weakref__
# Valor: None
# ----------------------------------
# Nombre: _append_device_id
# Valor: <bound method Spotify._append_device_id of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _auth
# Valor: BQCJxJiFrmzElCWtmUSUY3H-fCDyt84D4mHesXqSRO1J8UB1o9-_ngC5LX1gd7OpZ39UPHDeDrpUcUAMiziE0I74cuqDGSxfPFrxfW8NXvhtVC67wy5oN3enEVrfM5g2hLB9kfipIOHhTVvBf5R8z1WPwjyDvYH0OsWbGmTHJ6rBmXa8rwCu4pfuyRA
# ----------------------------------
# Nombre: _auth_headers
# Valor: <bound method Spotify._auth_headers of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _auth_manager
# Valor: None
# ----------------------------------
# Nombre: _build_session
# Valor: <bound method Spotify._build_session of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _delete
# Valor: <bound method Spotify._delete of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _get
# Valor: <bound method Spotify._get of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _get_id
# Valor: <bound method Spotify._get_id of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _get_uri
# Valor: <bound method Spotify._get_uri of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _internal_call
# Valor: <bound method Spotify._internal_call of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _is_uri
# Valor: <bound method Spotify._is_uri of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _post
# Valor: <bound method Spotify._post of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _put
# Valor: <bound method Spotify._put of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _regex_base62
# Valor: ^[0-9A-Za-z]+$
# ----------------------------------
# Nombre: _regex_spotify_uri
# Valor: ^spotify:(?:(?P<type>track|artist|album|playlist|show|episode):(?P<id>[0-9A-Za-z]+)|user:(?P<username>[0-9A-Za-z]+):playlist:(?P<playlistid>[0-9A-Za-z]+))$
# ----------------------------------
# Nombre: _regex_spotify_url
# Valor: ^(http[s]?:\/\/)?open.spotify.com\/(?P<type>track|artist|album|playlist|show|episode|user)\/(?P<id>[0-9A-Za-z]+)(\?.*)?$
# ----------------------------------
# Nombre: _search_multiple_markets
# Valor: <bound method Spotify._search_multiple_markets of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: _session
# Valor: <requests.sessions.Session object at 0x0000024EE7452A10>
# ----------------------------------
# Nombre: add_to_queue
# Valor: <bound method Spotify.add_to_queue of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: album
# Valor: <bound method Spotify.album of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: album_tracks
# Valor: <bound method Spotify.album_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: albums
# Valor: <bound method Spotify.albums of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: artist
# Valor: <bound method Spotify.artist of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: artist_albums
# Valor: <bound method Spotify.artist_albums of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: artist_related_artists
# Valor: <bound method Spotify.artist_related_artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: artist_top_tracks
# Valor: <bound method Spotify.artist_top_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: artists
# Valor: <bound method Spotify.artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: audio_analysis
# Valor: <bound method Spotify.audio_analysis of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: audio_features
# Valor: <bound method Spotify.audio_features of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: auth_manager
# Valor: None
# ----------------------------------
# Nombre: available_markets
# Valor: <bound method Spotify.available_markets of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: backoff_factor
# Valor: 0.3
# ----------------------------------
# Nombre: categories
# Valor: <bound method Spotify.categories of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: category
# Valor: <bound method Spotify.category of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: category_playlists
# Valor: <bound method Spotify.category_playlists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: client_credentials_manager
# Valor: None
# ----------------------------------
# Nombre: country_codes
# Valor: ['AD', 'AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'SV', 'EE', 'FI', 'FR', 'DE', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'ID', 'IE', 'IT', 'JP', 'LV', 'LI', 'LT', 'LU', 'MY', 'MT', 'MX', 'MC', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'ES', 'SK', 'SE', 'CH', 'TW', 'TR', 'GB', 'US', 'UY']
# ----------------------------------
# Nombre: current_playback
# Valor: <bound method Spotify.current_playback of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user
# Valor: <bound method Spotify.current_user of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_follow_playlist
# Valor: <bound method Spotify.current_user_follow_playlist of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_followed_artists
# Valor: <bound method Spotify.current_user_followed_artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_following_artists
# Valor: <bound method Spotify.current_user_following_artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_following_users
# Valor: <bound method Spotify.current_user_following_users of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_playing_track
# Valor: <bound method Spotify.current_user_playing_track of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_playlists
# Valor: <bound method Spotify.current_user_playlists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_recently_played
# Valor: <bound method Spotify.current_user_recently_played of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_albums
# Valor: <bound method Spotify.current_user_saved_albums of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_albums_add
# Valor: <bound method Spotify.current_user_saved_albums_add of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_albums_contains
# Valor: <bound method Spotify.current_user_saved_albums_contains of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_albums_delete
# Valor: <bound method Spotify.current_user_saved_albums_delete of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_episodes
# Valor: <bound method Spotify.current_user_saved_episodes of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_episodes_add
# Valor: <bound method Spotify.current_user_saved_episodes_add of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_episodes_contains
# Valor: <bound method Spotify.current_user_saved_episodes_contains of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_episodes_delete
# Valor: <bound method Spotify.current_user_saved_episodes_delete of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_shows
# Valor: <bound method Spotify.current_user_saved_shows of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_shows_add
# Valor: <bound method Spotify.current_user_saved_shows_add of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_shows_contains
# Valor: <bound method Spotify.current_user_saved_shows_contains of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_shows_delete
# Valor: <bound method Spotify.current_user_saved_shows_delete of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_tracks
# Valor: <bound method Spotify.current_user_saved_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_tracks_add
# Valor: <bound method Spotify.current_user_saved_tracks_add of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_tracks_contains
# Valor: <bound method Spotify.current_user_saved_tracks_contains of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_saved_tracks_delete
# Valor: <bound method Spotify.current_user_saved_tracks_delete of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_top_artists
# Valor: <bound method Spotify.current_user_top_artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_top_tracks
# Valor: <bound method Spotify.current_user_top_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: current_user_unfollow_playlist
# Valor: <bound method Spotify.current_user_unfollow_playlist of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: currently_playing
# Valor: <bound method Spotify.currently_playing of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: default_retry_codes
# Valor: (429, 500, 502, 503, 504)
# ----------------------------------
# Nombre: devices
# Valor: <bound method Spotify.devices of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: episode
# Valor: <bound method Spotify.episode of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: episodes
# Valor: <bound method Spotify.episodes of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: featured_playlists
# Valor: <bound method Spotify.featured_playlists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: language
# Valor: None
# ----------------------------------
# Nombre: max_retries
# Valor: 3
# ----------------------------------
# Nombre: me
# Valor: <bound method Spotify.me of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: new_releases
# Valor: <bound method Spotify.new_releases of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: next
# Valor: <bound method Spotify.next of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: next_track
# Valor: <bound method Spotify.next_track of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: oauth_manager
# Valor: None
# ----------------------------------
# Nombre: pause_playback
# Valor: <bound method Spotify.pause_playback of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist
# Valor: <bound method Spotify.playlist of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_add_items
# Valor: <bound method Spotify.playlist_add_items of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_change_details
# Valor: <bound method Spotify.playlist_change_details of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_cover_image
# Valor: <bound method Spotify.playlist_cover_image of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_is_following
# Valor: <bound method Spotify.playlist_is_following of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_items
# Valor: <bound method Spotify.playlist_items of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_remove_all_occurrences_of_items
# Valor: <bound method Spotify.playlist_remove_all_occurrences_of_items of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_remove_specific_occurrences_of_items
# Valor: <bound method Spotify.playlist_remove_specific_occurrences_of_items of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_reorder_items
# Valor: <bound method Spotify.playlist_reorder_items of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_replace_items
# Valor: <bound method Spotify.playlist_replace_items of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_tracks
# Valor: <bound method Spotify.playlist_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: playlist_upload_cover_image
# Valor: <bound method Spotify.playlist_upload_cover_image of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: prefix
# Valor: https://api.spotify.com/v1/
# ----------------------------------
# Nombre: previous
# Valor: <bound method Spotify.previous of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: previous_track
# Valor: <bound method Spotify.previous_track of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: proxies
# Valor: None
# ----------------------------------
# Nombre: queue
# Valor: <bound method Spotify.queue of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: recommendation_genre_seeds
# Valor: <bound method Spotify.recommendation_genre_seeds of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: recommendations
# Valor: <bound method Spotify.recommendations of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: repeat
# Valor: <bound method Spotify.repeat of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: requests_timeout
# Valor: 5
# ----------------------------------
# Nombre: retries
# Valor: 3
# ----------------------------------
# Nombre: search
# Valor: <bound method Spotify.search of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: search_markets
# Valor: <bound method Spotify.search_markets of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: seek_track
# Valor: <bound method Spotify.seek_track of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: set_auth
# Valor: <bound method Spotify.set_auth of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: show
# Valor: <bound method Spotify.show of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: show_episodes
# Valor: <bound method Spotify.show_episodes of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: shows
# Valor: <bound method Spotify.shows of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: shuffle
# Valor: <bound method Spotify.shuffle of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: start_playback
# Valor: <bound method Spotify.start_playback of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: status_forcelist
# Valor: (429, 500, 502, 503, 504)
# ----------------------------------
# Nombre: status_retries
# Valor: 3
# ----------------------------------
# Nombre: track
# Valor: <bound method Spotify.track of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: tracks
# Valor: <bound method Spotify.tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: transfer_playback
# Valor: <bound method Spotify.transfer_playback of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user
# Valor: <bound method Spotify.user of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_follow_artists
# Valor: <bound method Spotify.user_follow_artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_follow_users
# Valor: <bound method Spotify.user_follow_users of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist
# Valor: <bound method Spotify.user_playlist of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_add_episodes
# Valor: <bound method Spotify.user_playlist_add_episodes of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_add_tracks
# Valor: <bound method Spotify.user_playlist_add_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_change_details
# Valor: <bound method Spotify.user_playlist_change_details of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_create
# Valor: <bound method Spotify.user_playlist_create of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_follow_playlist
# Valor: <bound method Spotify.user_playlist_follow_playlist of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_is_following
# Valor: <bound method Spotify.user_playlist_is_following of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_remove_all_occurrences_of_tracks
# Valor: <bound method Spotify.user_playlist_remove_all_occurrences_of_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_remove_specific_occurrences_of_tracks
# Valor: <bound method Spotify.user_playlist_remove_specific_occurrences_of_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_reorder_tracks
# Valor: <bound method Spotify.user_playlist_reorder_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_replace_tracks
# Valor: <bound method Spotify.user_playlist_replace_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_tracks
# Valor: <bound method Spotify.user_playlist_tracks of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlist_unfollow
# Valor: <bound method Spotify.user_playlist_unfollow of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_playlists
# Valor: <bound method Spotify.user_playlists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_unfollow_artists
# Valor: <bound method Spotify.user_unfollow_artists of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: user_unfollow_users
# Valor: <bound method Spotify.user_unfollow_users of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------
# Nombre: volume
# Valor: <bound method Spotify.volume of <spotipy.client.Spotify object at 0x0000024EE7452290>>
# ----------------------------------

# %%
# Obtener información sobre el método
informacion_metodo = inspect.getmembers(sp.current_user_top_tracks)

# Imprimir información sobre el método
for nombre, valor in informacion_metodo:
    print(f"Nombre: {nombre}")
    print(f"Valor: {valor}")
    print("----------------------------------")
# Out:
# Nombre: __call__
# Valor: <method-wrapper '__call__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __class__
# Valor: <class 'method'>
# ----------------------------------
# Nombre: __delattr__
# Valor: <method-wrapper '__delattr__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __dir__
# Valor: <built-in method __dir__ of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __doc__
# Valor:  Get the current user's top tracks
#
#             Parameters:
#                 - limit - the number of entities to return
#                 - offset - the index of the first entity to return
#                 - time_range - Over what time frame are the affinities computed
#                   Valid-values: short_term, medium_term, long_term
#
# ----------------------------------
# Nombre: __eq__
# Valor: <method-wrapper '__eq__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __format__
# Valor: <built-in method __format__ of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __func__
# Valor: <function Spotify.current_user_top_tracks at 0x0000024EDE65AC20>
# ----------------------------------
# Nombre: __ge__
# Valor: <method-wrapper '__ge__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __get__
# Valor: <method-wrapper '__get__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __getattribute__
# Valor: <method-wrapper '__getattribute__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __gt__
# Valor: <method-wrapper '__gt__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __hash__
# Valor: <method-wrapper '__hash__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __init__
# Valor: <method-wrapper '__init__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __init_subclass__
# Valor: <built-in method __init_subclass__ of type object at 0x00007FFEDF8A6990>
# ----------------------------------
# Nombre: __le__
# Valor: <method-wrapper '__le__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __lt__
# Valor: <method-wrapper '__lt__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __ne__
# Valor: <method-wrapper '__ne__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __new__
# Valor: <built-in method __new__ of type object at 0x00007FFEDF8A6990>
# ----------------------------------
# Nombre: __reduce__
# Valor: <built-in method __reduce__ of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __reduce_ex__
# Valor: <built-in method __reduce_ex__ of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __repr__
# Valor: <method-wrapper '__repr__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __self__
# Valor: <spotipy.client.Spotify object at 0x0000024EE7452290>
# ----------------------------------
# Nombre: __setattr__
# Valor: <method-wrapper '__setattr__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __sizeof__
# Valor: <built-in method __sizeof__ of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __str__
# Valor: <method-wrapper '__str__' of method object at 0x0000024EE64FE1C0>
# ----------------------------------
# Nombre: __subclasshook__
# Valor: <built-in method __subclasshook__ of type object at 0x00007FFEDF8A6990>
# ----------------------------------

# %% [markdown]
# ### Top 20
# La información que está a punto de cargarles es la info de uno de los integrantes del proyecto.
# Para empezar vamos a usar el top de las canciones escuchadas por el usuario principal

# %%
firma_metodo = inspect.signature(sp.current_user_top_tracks)
nombres_argumentos = [parametro.name for parametro in firma_metodo.parameters.values()]
for nombre in nombres_argumentos:
    print(nombre)
# Out:
# limit
# offset
# time_range

# %%
top20 = sp.current_user_top_tracks(time_range='short_term', limit = 20)

# %% [markdown]
# De acá nos podemos dar de cuenta de todas las variables que tenemos disponibles del top 20.

# %%
top20 # Diccionario
# Out:
# {'items': [{'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uSVRVjYZ0PlJPdFHnBETu'},
#       'href': 'https://api.spotify.com/v1/artists/2uSVRVjYZ0PlJPdFHnBETu',
#       'id': '2uSVRVjYZ0PlJPdFHnBETu',
#       'name': 'creamy',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uSVRVjYZ0PlJPdFHnBETu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/31mtcsgS3CJW5dEPlG83E7'},
#       'href': 'https://api.spotify.com/v1/artists/31mtcsgS3CJW5dEPlG83E7',
#       'id': '31mtcsgS3CJW5dEPlG83E7',
#       'name': 'untrusted',
#       'type': 'artist',
#       'uri': 'spotify:artist:31mtcsgS3CJW5dEPlG83E7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MDj296KJIfgWDNBtHzeFi'},
#       'href': 'https://api.spotify.com/v1/artists/2MDj296KJIfgWDNBtHzeFi',
#       'id': '2MDj296KJIfgWDNBtHzeFi',
#       'name': '11:11 Music Group',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MDj296KJIfgWDNBtHzeFi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7pXjin5WJrTKEGzpkshxO3'},
#     'href': 'https://api.spotify.com/v1/albums/7pXjin5WJrTKEGzpkshxO3',
#     'id': '7pXjin5WJrTKEGzpkshxO3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c71a669d8b229cec972f6ed5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c71a669d8b229cec972f6ed5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c71a669d8b229cec972f6ed5',
#       'width': 64}],
#     'name': 'Do I Wanna Know (8D Audio)',
#     'release_date': '2021-01-19',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7pXjin5WJrTKEGzpkshxO3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uSVRVjYZ0PlJPdFHnBETu'},
#      'href': 'https://api.spotify.com/v1/artists/2uSVRVjYZ0PlJPdFHnBETu',
#      'id': '2uSVRVjYZ0PlJPdFHnBETu',
#      'name': 'creamy',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uSVRVjYZ0PlJPdFHnBETu'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/31mtcsgS3CJW5dEPlG83E7'},
#      'href': 'https://api.spotify.com/v1/artists/31mtcsgS3CJW5dEPlG83E7',
#      'id': '31mtcsgS3CJW5dEPlG83E7',
#      'name': 'untrusted',
#      'type': 'artist',
#      'uri': 'spotify:artist:31mtcsgS3CJW5dEPlG83E7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MDj296KJIfgWDNBtHzeFi'},
#      'href': 'https://api.spotify.com/v1/artists/2MDj296KJIfgWDNBtHzeFi',
#      'id': '2MDj296KJIfgWDNBtHzeFi',
#      'name': '11:11 Music Group',
#      'type': 'artist',
#      'uri': 'spotify:artist:2MDj296KJIfgWDNBtHzeFi'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 203983,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBSMU9410123'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6dvGAhdmKhA4XTXkmo588g'},
#    'href': 'https://api.spotify.com/v1/tracks/6dvGAhdmKhA4XTXkmo588g',
#    'id': '6dvGAhdmKhA4XTXkmo588g',
#    'is_local': False,
#    'name': 'Do I Wanna Know (8D Audio)',
#    'popularity': 45,
#    'preview_url': 'https://p.scdn.co/mp3-preview/72a8756664d82710fd8736fba5e0293c86f5c249?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6dvGAhdmKhA4XTXkmo588g'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#       'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#       'id': '1WgXqy2Dd70QQOU7Ay074N',
#       'name': 'AURORA',
#       'type': 'artist',
#       'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'OM',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UY',
#      'VN'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2HPgGJnpimfmFPMjP0syqY'},
#     'href': 'https://api.spotify.com/v1/albums/2HPgGJnpimfmFPMjP0syqY',
#     'id': '2HPgGJnpimfmFPMjP0syqY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733e0d05346299e86c58f75123',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023e0d05346299e86c58f75123',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513e0d05346299e86c58f75123',
#       'width': 64}],
#     'name': 'The Gods We Can Touch',
#     'release_date': '2022-01-21',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:2HPgGJnpimfmFPMjP0syqY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#      'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#      'id': '1WgXqy2Dd70QQOU7Ay074N',
#      'name': 'AURORA',
#      'type': 'artist',
#      'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'HK',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MY',
#     'NL',
#     'OM',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UY',
#     'VN'],
#    'disc_number': 1,
#    'duration_ms': 213906,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM72102600'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1rMlnD8S0hX7IHZXZDt3gH'},
#    'href': 'https://api.spotify.com/v1/tracks/1rMlnD8S0hX7IHZXZDt3gH',
#    'id': '1rMlnD8S0hX7IHZXZDt3gH',
#    'is_local': False,
#    'name': 'Everything Matters',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8a27176e87a2eec4dda52d31549a090e1ee429ad?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1rMlnD8S0hX7IHZXZDt3gH'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1He0ZKninbT4FMEV9hUZKn'},
#       'href': 'https://api.spotify.com/v1/artists/1He0ZKninbT4FMEV9hUZKn',
#       'id': '1He0ZKninbT4FMEV9hUZKn',
#       'name': 'Mindchatter',
#       'type': 'artist',
#       'uri': 'spotify:artist:1He0ZKninbT4FMEV9hUZKn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5cupSOKi7oIVsQ1LfpWKqv'},
#     'href': 'https://api.spotify.com/v1/albums/5cupSOKi7oIVsQ1LfpWKqv',
#     'id': '5cupSOKi7oIVsQ1LfpWKqv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dbdeab6f438d420099673331',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dbdeab6f438d420099673331',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dbdeab6f438d420099673331',
#       'width': 64}],
#     'name': 'Imaginary Audience',
#     'release_date': '2020-10-21',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5cupSOKi7oIVsQ1LfpWKqv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1He0ZKninbT4FMEV9hUZKn'},
#      'href': 'https://api.spotify.com/v1/artists/1He0ZKninbT4FMEV9hUZKn',
#      'id': '1He0ZKninbT4FMEV9hUZKn',
#      'name': 'Mindchatter',
#      'type': 'artist',
#      'uri': 'spotify:artist:1He0ZKninbT4FMEV9hUZKn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 201255,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZMEM2002279'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1WqgjwwlLRKE6qtcUY37S1'},
#    'href': 'https://api.spotify.com/v1/tracks/1WqgjwwlLRKE6qtcUY37S1',
#    'id': '1WqgjwwlLRKE6qtcUY37S1',
#    'is_local': False,
#    'name': 'Blame Game',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/879ca4433fffb3532e4b9ade95b4511d7178d2d9?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1WqgjwwlLRKE6qtcUY37S1'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#       'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#       'id': '2qk9voo8llSGYcZ6xrBzKx',
#       'name': 'Kings of Leon',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5CZR6ljD0x9fTiS4mh9wMp'},
#     'href': 'https://api.spotify.com/v1/albums/5CZR6ljD0x9fTiS4mh9wMp',
#     'id': '5CZR6ljD0x9fTiS4mh9wMp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732519d01c0cca06f134eeadd8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022519d01c0cca06f134eeadd8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512519d01c0cca06f134eeadd8',
#       'width': 64}],
#     'name': 'Only By The Night',
#     'release_date': '2008-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5CZR6ljD0x9fTiS4mh9wMp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#      'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#      'id': '2qk9voo8llSGYcZ6xrBzKx',
#      'name': 'Kings of Leon',
#      'type': 'artist',
#      'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 203346,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10800300'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45'},
#    'href': 'https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45',
#    'id': '0ntQJM78wzOLVeCUAW7Y45',
#    'is_local': False,
#    'name': 'Sex on Fire',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6806855988e246016413cc8a34a2afe862f3988d?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0ntQJM78wzOLVeCUAW7Y45'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#       'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#       'id': '0L8ExT028jH3ddEcZwqJJ5',
#       'name': 'Red Hot Chili Peppers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#     'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#     'id': '2Y9IRtehByVkegoD7TcLfi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#       'width': 64}],
#     'name': 'Californication (Deluxe Edition)',
#     'release_date': '1999-06-08',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#      'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#      'id': '0L8ExT028jH3ddEcZwqJJ5',
#      'name': 'Red Hot Chili Peppers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 329733,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB19900690'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/48UPSzbZjgc449aqz8bxox'},
#    'href': 'https://api.spotify.com/v1/tracks/48UPSzbZjgc449aqz8bxox',
#    'id': '48UPSzbZjgc449aqz8bxox',
#    'is_local': False,
#    'name': 'Californication',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0fd595c5b63db10f4a99683f8248ea5d13700683?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:48UPSzbZjgc449aqz8bxox'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bq8rqNnfrojn0OSAfeNXJ'},
#       'href': 'https://api.spotify.com/v1/artists/1bq8rqNnfrojn0OSAfeNXJ',
#       'id': '1bq8rqNnfrojn0OSAfeNXJ',
#       'name': 'Sarcastic Sounds',
#       'type': 'artist',
#       'uri': 'spotify:artist:1bq8rqNnfrojn0OSAfeNXJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1EmJAmRdDyfQAqhXOvKzSB'},
#     'href': 'https://api.spotify.com/v1/albums/1EmJAmRdDyfQAqhXOvKzSB',
#     'id': '1EmJAmRdDyfQAqhXOvKzSB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738d25d43fb77a28a82d3d342c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028d25d43fb77a28a82d3d342c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518d25d43fb77a28a82d3d342c',
#       'width': 64}],
#     'name': 'say goodbye',
#     'release_date': '2021-05-14',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:1EmJAmRdDyfQAqhXOvKzSB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bq8rqNnfrojn0OSAfeNXJ'},
#      'href': 'https://api.spotify.com/v1/artists/1bq8rqNnfrojn0OSAfeNXJ',
#      'id': '1bq8rqNnfrojn0OSAfeNXJ',
#      'name': 'Sarcastic Sounds',
#      'type': 'artist',
#      'uri': 'spotify:artist:1bq8rqNnfrojn0OSAfeNXJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 86749,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM12102222'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6JdU7eaEl9fPAq0sEVNzGc'},
#    'href': 'https://api.spotify.com/v1/tracks/6JdU7eaEl9fPAq0sEVNzGc',
#    'id': '6JdU7eaEl9fPAq0sEVNzGc',
#    'is_local': False,
#    'name': 'say goodbye',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3d6115ee10671e36f44cf5d3b6f16d444aca6175?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6JdU7eaEl9fPAq0sEVNzGc'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KBPxIED8ejHkvhs4KCzyS'},
#       'href': 'https://api.spotify.com/v1/artists/5KBPxIED8ejHkvhs4KCzyS',
#       'id': '5KBPxIED8ejHkvhs4KCzyS',
#       'name': 'Granuja',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KBPxIED8ejHkvhs4KCzyS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/31HSq8pOXZCts7GqWXTRU1'},
#     'href': 'https://api.spotify.com/v1/albums/31HSq8pOXZCts7GqWXTRU1',
#     'id': '31HSq8pOXZCts7GqWXTRU1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27334133a7eeb7bbef836ec7737',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0234133a7eeb7bbef836ec7737',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485134133a7eeb7bbef836ec7737',
#       'width': 64}],
#     'name': 'Círculo Vicioso',
#     'release_date': '2017-03-31',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:31HSq8pOXZCts7GqWXTRU1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KBPxIED8ejHkvhs4KCzyS'},
#      'href': 'https://api.spotify.com/v1/artists/5KBPxIED8ejHkvhs4KCzyS',
#      'id': '5KBPxIED8ejHkvhs4KCzyS',
#      'name': 'Granuja',
#      'type': 'artist',
#      'uri': 'spotify:artist:5KBPxIED8ejHkvhs4KCzyS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 263023,
#    'explicit': False,
#    'external_ids': {'isrc': 'US7VG1733018'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/77ozYKcoGc9Cc6M9wRZH9d'},
#    'href': 'https://api.spotify.com/v1/tracks/77ozYKcoGc9Cc6M9wRZH9d',
#    'id': '77ozYKcoGc9Cc6M9wRZH9d',
#    'is_local': False,
#    'name': 'De Pe a Pa',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cbcdc304e82acfaa7bcd51dbc845c62e1dc9b725?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:77ozYKcoGc9Cc6M9wRZH9d'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#       'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#       'id': '5eAWCfyUhZtHHtBdNk56l1',
#       'name': 'System Of A Down',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6jWde94ln40epKIQCd8XUh'},
#     'href': 'https://api.spotify.com/v1/albums/6jWde94ln40epKIQCd8XUh',
#     'id': '6jWde94ln40epKIQCd8XUh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27330d45198d0c9e8841f9a9578',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0230d45198d0c9e8841f9a9578',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485130d45198d0c9e8841f9a9578',
#       'width': 64}],
#     'name': 'Toxicity',
#     'release_date': '2001-09-04',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:6jWde94ln40epKIQCd8XUh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#      'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#      'id': '5eAWCfyUhZtHHtBdNk56l1',
#      'name': 'System Of A Down',
#      'type': 'artist',
#      'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 218933,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10107262'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0snQkGI5qnAmohLE7jTsTn'},
#    'href': 'https://api.spotify.com/v1/tracks/0snQkGI5qnAmohLE7jTsTn',
#    'id': '0snQkGI5qnAmohLE7jTsTn',
#    'is_local': False,
#    'name': 'Toxicity',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d9b89161dacbb987b360417346591712c4023abd?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:0snQkGI5qnAmohLE7jTsTn'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5g03v1dieHbVUP47XeXk7H'},
#       'href': 'https://api.spotify.com/v1/artists/5g03v1dieHbVUP47XeXk7H',
#       'id': '5g03v1dieHbVUP47XeXk7H',
#       'name': 'La Etnnia',
#       'type': 'artist',
#       'uri': 'spotify:artist:5g03v1dieHbVUP47XeXk7H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6hKScNAjmff6t6l2qLCHhL'},
#     'href': 'https://api.spotify.com/v1/albums/6hKScNAjmff6t6l2qLCHhL',
#     'id': '6hKScNAjmff6t6l2qLCHhL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735bf8ed5ab2ee47dfb47a7866',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025bf8ed5ab2ee47dfb47a7866',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515bf8ed5ab2ee47dfb47a7866',
#       'width': 64}],
#     'name': 'El Ataque del Metano',
#     'release_date': '1995-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6hKScNAjmff6t6l2qLCHhL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5g03v1dieHbVUP47XeXk7H'},
#      'href': 'https://api.spotify.com/v1/artists/5g03v1dieHbVUP47XeXk7H',
#      'id': '5g03v1dieHbVUP47XeXk7H',
#      'name': 'La Etnnia',
#      'type': 'artist',
#      'uri': 'spotify:artist:5g03v1dieHbVUP47XeXk7H'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 250586,
#    'explicit': True,
#    'external_ids': {'isrc': 'USCGJ1508386'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3IalZWzPrxDvh3n2hNBSKI'},
#    'href': 'https://api.spotify.com/v1/tracks/3IalZWzPrxDvh3n2hNBSKI',
#    'id': '3IalZWzPrxDvh3n2hNBSKI',
#    'is_local': False,
#    'name': 'Noicanicula',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/65961bb6726b046719cd38d5683392d15da02166?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:3IalZWzPrxDvh3n2hNBSKI'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#       'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#       'id': '7jy3rLJdDQY21OgRLCZ9sD',
#       'name': 'Foo Fighters',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3ilXDEG0xiajK8AbqboeJz'},
#     'href': 'https://api.spotify.com/v1/albums/3ilXDEG0xiajK8AbqboeJz',
#     'id': '3ilXDEG0xiajK8AbqboeJz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27383e260c313dc1ff1f17909cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0283e260c313dc1ff1f17909cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485183e260c313dc1ff1f17909cf',
#       'width': 64}],
#     'name': 'Echoes, Silence, Patience & Grace',
#     'release_date': '2007-09-25',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3ilXDEG0xiajK8AbqboeJz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#      'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#      'id': '7jy3rLJdDQY21OgRLCZ9sD',
#      'name': 'Foo Fighters',
#      'type': 'artist',
#      'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 269373,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRW30700007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7x8dCjCr0x6x2lXKujYD34'},
#    'href': 'https://api.spotify.com/v1/tracks/7x8dCjCr0x6x2lXKujYD34',
#    'id': '7x8dCjCr0x6x2lXKujYD34',
#    'is_local': False,
#    'name': 'The Pretender',
#    'popularity': 81,
#    'preview_url': 'https://p.scdn.co/mp3-preview/23a6ace3679431062d5e6f0bc60a514f3a26da4e?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7x8dCjCr0x6x2lXKujYD34'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KBPxIED8ejHkvhs4KCzyS'},
#       'href': 'https://api.spotify.com/v1/artists/5KBPxIED8ejHkvhs4KCzyS',
#       'id': '5KBPxIED8ejHkvhs4KCzyS',
#       'name': 'Granuja',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KBPxIED8ejHkvhs4KCzyS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/128Quqrd9Nqtnq8NtXyQQi'},
#     'href': 'https://api.spotify.com/v1/albums/128Quqrd9Nqtnq8NtXyQQi',
#     'id': '128Quqrd9Nqtnq8NtXyQQi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732ed6d7b6542a09ec40946198',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022ed6d7b6542a09ec40946198',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512ed6d7b6542a09ec40946198',
#       'width': 64}],
#     'name': 'Selección Natural',
#     'release_date': '2018-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:128Quqrd9Nqtnq8NtXyQQi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KBPxIED8ejHkvhs4KCzyS'},
#      'href': 'https://api.spotify.com/v1/artists/5KBPxIED8ejHkvhs4KCzyS',
#      'id': '5KBPxIED8ejHkvhs4KCzyS',
#      'name': 'Granuja',
#      'type': 'artist',
#      'uri': 'spotify:artist:5KBPxIED8ejHkvhs4KCzyS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 84782,
#    'explicit': False,
#    'external_ids': {'isrc': 'US7VG1841480'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6exIUuLIkxbChmk73bMBJ4'},
#    'href': 'https://api.spotify.com/v1/tracks/6exIUuLIkxbChmk73bMBJ4',
#    'id': '6exIUuLIkxbChmk73bMBJ4',
#    'is_local': False,
#    'name': 'Ateo',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2edffd440f3431bdabda1734064e3746ecc91d7e?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6exIUuLIkxbChmk73bMBJ4'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4PLGokgPkAapRsKDwXq408'},
#       'href': 'https://api.spotify.com/v1/artists/4PLGokgPkAapRsKDwXq408',
#       'id': '4PLGokgPkAapRsKDwXq408',
#       'name': 'Doble Porcion',
#       'type': 'artist',
#       'uri': 'spotify:artist:4PLGokgPkAapRsKDwXq408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/10MeG72hSqEKGbUdBowf9k'},
#       'href': 'https://api.spotify.com/v1/artists/10MeG72hSqEKGbUdBowf9k',
#       'id': '10MeG72hSqEKGbUdBowf9k',
#       'name': 'Métricas Frías',
#       'type': 'artist',
#       'uri': 'spotify:artist:10MeG72hSqEKGbUdBowf9k'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/78rkeQAvjl85yNyLAqEMVe'},
#       'href': 'https://api.spotify.com/v1/artists/78rkeQAvjl85yNyLAqEMVe',
#       'id': '78rkeQAvjl85yNyLAqEMVe',
#       'name': 'Mañas Ru-Fino',
#       'type': 'artist',
#       'uri': 'spotify:artist:78rkeQAvjl85yNyLAqEMVe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4I6lImrXf0vqIjtsPQoOWJ'},
#     'href': 'https://api.spotify.com/v1/albums/4I6lImrXf0vqIjtsPQoOWJ',
#     'id': '4I6lImrXf0vqIjtsPQoOWJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27328f61734580994bdf0819891',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0228f61734580994bdf0819891',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485128f61734580994bdf0819891',
#       'width': 64}],
#     'name': 'Manzanas a la Vuelta',
#     'release_date': '2016-09-16',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:4I6lImrXf0vqIjtsPQoOWJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4PLGokgPkAapRsKDwXq408'},
#      'href': 'https://api.spotify.com/v1/artists/4PLGokgPkAapRsKDwXq408',
#      'id': '4PLGokgPkAapRsKDwXq408',
#      'name': 'Doble Porcion',
#      'type': 'artist',
#      'uri': 'spotify:artist:4PLGokgPkAapRsKDwXq408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/10MeG72hSqEKGbUdBowf9k'},
#      'href': 'https://api.spotify.com/v1/artists/10MeG72hSqEKGbUdBowf9k',
#      'id': '10MeG72hSqEKGbUdBowf9k',
#      'name': 'Métricas Frías',
#      'type': 'artist',
#      'uri': 'spotify:artist:10MeG72hSqEKGbUdBowf9k'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/78rkeQAvjl85yNyLAqEMVe'},
#      'href': 'https://api.spotify.com/v1/artists/78rkeQAvjl85yNyLAqEMVe',
#      'id': '78rkeQAvjl85yNyLAqEMVe',
#      'name': 'Mañas Ru-Fino',
#      'type': 'artist',
#      'uri': 'spotify:artist:78rkeQAvjl85yNyLAqEMVe'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 156521,
#    'explicit': True,
#    'external_ids': {'isrc': 'US7VG1689623'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/17tWQcqeNO4Hh0RF9gJcvO'},
#    'href': 'https://api.spotify.com/v1/tracks/17tWQcqeNO4Hh0RF9gJcvO',
#    'id': '17tWQcqeNO4Hh0RF9gJcvO',
#    'is_local': False,
#    'name': "Roca N' Ron",
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/003fc5ee658e255d49068c69ebc51deac8555a65?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:17tWQcqeNO4Hh0RF9gJcvO'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EXpthNgSeTDeX8nGwxppp'},
#       'href': 'https://api.spotify.com/v1/artists/2EXpthNgSeTDeX8nGwxppp',
# ...
#       'id': '5KBPxIED8ejHkvhs4KCzyS',
#       'name': 'Granuja',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KBPxIED8ejHkvhs4KCzyS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6G7bf3U6XL6Fo0E2yh8MXD'},
#     'href': 'https://api.spotify.com/v1/albums/6G7bf3U6XL6Fo0E2yh8MXD',
#     'id': '6G7bf3U6XL6Fo0E2yh8MXD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27312337611939b897b7b24fae9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0212337611939b897b7b24fae9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485112337611939b897b7b24fae9',
#       'width': 64}],
#     'name': 'Vergüenza Propia',
#     'release_date': '2019-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6G7bf3U6XL6Fo0E2yh8MXD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KBPxIED8ejHkvhs4KCzyS'},
#      'href': 'https://api.spotify.com/v1/artists/5KBPxIED8ejHkvhs4KCzyS',
#      'id': '5KBPxIED8ejHkvhs4KCzyS',
#      'name': 'Granuja',
#      'type': 'artist',
#      'uri': 'spotify:artist:5KBPxIED8ejHkvhs4KCzyS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 212045,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZHZ31962625'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Y279nOMn5B8FR7Qb86P5j'},
#    'href': 'https://api.spotify.com/v1/tracks/6Y279nOMn5B8FR7Qb86P5j',
#    'id': '6Y279nOMn5B8FR7Qb86P5j',
#    'is_local': False,
#    'name': 'Días de Perros',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d35a8bf6f8168ca2020dc881420d37386d80b277?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6Y279nOMn5B8FR7Qb86P5j'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5kROocD0ED0BYdVo7tJrSe'},
#       'href': 'https://api.spotify.com/v1/artists/5kROocD0ED0BYdVo7tJrSe',
#       'id': '5kROocD0ED0BYdVo7tJrSe',
#       'name': 'Tres Coronas',
#       'type': 'artist',
#       'uri': 'spotify:artist:5kROocD0ED0BYdVo7tJrSe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1tNK99WiqFYnOf86u5amUy'},
#     'href': 'https://api.spotify.com/v1/albums/1tNK99WiqFYnOf86u5amUy',
#     'id': '1tNK99WiqFYnOf86u5amUy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eccc14df82820d011e5f191e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eccc14df82820d011e5f191e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eccc14df82820d011e5f191e',
#       'width': 64}],
#     'name': 'Mixtape Remix',
#     'release_date': '2005-04-12',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:1tNK99WiqFYnOf86u5amUy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5kROocD0ED0BYdVo7tJrSe'},
#      'href': 'https://api.spotify.com/v1/artists/5kROocD0ED0BYdVo7tJrSe',
#      'id': '5kROocD0ED0BYdVo7tJrSe',
#      'name': 'Tres Coronas',
#      'type': 'artist',
#      'uri': 'spotify:artist:5kROocD0ED0BYdVo7tJrSe'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 280673,
#    'explicit': True,
#    'external_ids': {'isrc': 'US7VG1631852'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6pck8FLAH6JMdf62b739KF'},
#    'href': 'https://api.spotify.com/v1/tracks/6pck8FLAH6JMdf62b739KF',
#    'id': '6pck8FLAH6JMdf62b739KF',
#    'is_local': False,
#    'name': 'Falsedades',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/af76b60b8c027ba2ab758640e7abd574792fbd4d?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:6pck8FLAH6JMdf62b739KF'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#       'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#       'id': '6olE6TJLqED3rqDCT0FyPh',
#       'name': 'Nirvana',
#       'type': 'artist',
#       'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2UJcKiJxNryhL050F5Z1Fk'},
#     'href': 'https://api.spotify.com/v1/albums/2UJcKiJxNryhL050F5Z1Fk',
#     'id': '2UJcKiJxNryhL050F5Z1Fk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fbc71c99f9c1296c56dd51b6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fbc71c99f9c1296c56dd51b6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fbc71c99f9c1296c56dd51b6',
#       'width': 64}],
#     'name': 'Nevermind (Remastered)',
#     'release_date': '1991-09-26',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:2UJcKiJxNryhL050F5Z1Fk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 232146,
#    'explicit': False,
#    'external_ids': {'isrc': 'USGF19942512'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4gHnSNHs8RyVukKoWdS99f'},
#    'href': 'https://api.spotify.com/v1/tracks/4gHnSNHs8RyVukKoWdS99f',
#    'id': '4gHnSNHs8RyVukKoWdS99f',
#    'is_local': False,
#    'name': 'Something In The Way',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/754f72b8e7b76c22f0d758d1ab39bd7ebc841ed6?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:4gHnSNHs8RyVukKoWdS99f'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NcNqG01boinOKgb7ImmEJ'},
#       'href': 'https://api.spotify.com/v1/artists/0NcNqG01boinOKgb7ImmEJ',
#       'id': '0NcNqG01boinOKgb7ImmEJ',
#       'name': 'Vic Deal',
#       'type': 'artist',
#       'uri': 'spotify:artist:0NcNqG01boinOKgb7ImmEJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6IQraFTvYMjzlx6AsrmsuB'},
#       'href': 'https://api.spotify.com/v1/artists/6IQraFTvYMjzlx6AsrmsuB',
#       'id': '6IQraFTvYMjzlx6AsrmsuB',
#       'name': 'Luis7Lunes',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IQraFTvYMjzlx6AsrmsuB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/29W1vGuAmmxv2FhBDxmCg9'},
#       'href': 'https://api.spotify.com/v1/artists/29W1vGuAmmxv2FhBDxmCg9',
#       'id': '29W1vGuAmmxv2FhBDxmCg9',
#       'name': 'Maco Maat',
#       'type': 'artist',
#       'uri': 'spotify:artist:29W1vGuAmmxv2FhBDxmCg9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1IhpWy754CmLzQNodX3bvN'},
#     'href': 'https://api.spotify.com/v1/albums/1IhpWy754CmLzQNodX3bvN',
#     'id': '1IhpWy754CmLzQNodX3bvN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735ab8fbf0b30d5c548bfabb04',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025ab8fbf0b30d5c548bfabb04',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515ab8fbf0b30d5c548bfabb04',
#       'width': 64}],
#     'name': 'Rap Cum Laude',
#     'release_date': '2022-11-11',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1IhpWy754CmLzQNodX3bvN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NcNqG01boinOKgb7ImmEJ'},
#      'href': 'https://api.spotify.com/v1/artists/0NcNqG01boinOKgb7ImmEJ',
#      'id': '0NcNqG01boinOKgb7ImmEJ',
#      'name': 'Vic Deal',
#      'type': 'artist',
#      'uri': 'spotify:artist:0NcNqG01boinOKgb7ImmEJ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6IQraFTvYMjzlx6AsrmsuB'},
#      'href': 'https://api.spotify.com/v1/artists/6IQraFTvYMjzlx6AsrmsuB',
#      'id': '6IQraFTvYMjzlx6AsrmsuB',
#      'name': 'Luis7Lunes',
#      'type': 'artist',
#      'uri': 'spotify:artist:6IQraFTvYMjzlx6AsrmsuB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/29W1vGuAmmxv2FhBDxmCg9'},
#      'href': 'https://api.spotify.com/v1/artists/29W1vGuAmmxv2FhBDxmCg9',
#      'id': '29W1vGuAmmxv2FhBDxmCg9',
#      'name': 'Maco Maat',
#      'type': 'artist',
#      'uri': 'spotify:artist:29W1vGuAmmxv2FhBDxmCg9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 232375,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZNJZ2228345'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3nOBpDknEXqdnDx2m0clej'},
#    'href': 'https://api.spotify.com/v1/tracks/3nOBpDknEXqdnDx2m0clej',
#    'id': '3nOBpDknEXqdnDx2m0clej',
#    'is_local': False,
#    'name': 'El Emblema',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/aada7ea9468ce603c667058b5fa27ba6382f9902?cid=70c4eff7ab204aeaaa1ee54e6304f766',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:3nOBpDknEXqdnDx2m0clej'}],
#  'total': 50,
#  'limit': 20,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=20&offset=20&time_range=short_term',
#  'previous': None}

# %% [markdown]
# Ahora, para empezar numeraremos el nombre de la canción y los artistas respectivamente.

# %%
for i,item in enumerate (top20['items']):
    print(i+1 , item['name'],'-',item['artists'][0]['name'])
# Out:
# 1 Do I Wanna Know (8D Audio) - creamy
# 2 Everything Matters - AURORA
# 3 Blame Game - Mindchatter
# 4 Sex on Fire - Kings of Leon
# 5 Californication - Red Hot Chili Peppers
# 6 say goodbye - Sarcastic Sounds
# 7 De Pe a Pa - Granuja
# 8 Toxicity - System Of A Down
# 9 Noicanicula - La Etnnia
# 10 The Pretender - Foo Fighters
# 11 Ateo - Granuja
# 12 Roca N' Ron - Doble Porcion
# 13 It's Called: Freefall - Paris Paloma
# 14 Quién Pidió Pollo - Granuja
# 15 Faint - Linkin Park
# 16 Under Kings - Granuja
# 17 Días de Perros - Granuja
# 18 Falsedades - Tres Coronas
# 19 Something In The Way - Nirvana
# 20 El Emblema - Vic Deal

# %% [markdown]
# ### Extracción de la información
# Para empezar, nos interesa extraer información de cada una de las canciones del top 20 del usuario, a continuación crearemos un dataframe que guardará:
# * Nombre de la canción
# * Id de la canción
# * Caracteristicas de la canción
#
# Un paso interesante es que, recién conocemos el ID de la canción vamos a buscar sus características usando el objeto ```sp```.

# %%
import pandas as pd # Importar pandas 

tracks = top20['items'] # Llamando el valor Items del diccionario Top 20
# Declarar listas vacías para guardar la información
track_ids = []
track_names = []
features = []
# Almacenar la información de las canciones de Top 20
for track in tracks:
    track_id = track['id'] # Guarda el ID de las canciones
    track_name = track['name'] # Guarda el nombre de las canciones
    audio_features = sp.audio_features(track_id) # Guarda las caracteristicas de las canciones partir de su ID
    
    track_ids.append(track_id)
    track_names.append(track_name)
    features.append(audio_features[0])

# %%
top20_df = pd.DataFrame(features,index = track_names)
top20_df.head(n = 2)
# Out:
#                             danceability  energy  key  loudness  mode  \
# Do I Wanna Know (8D Audio)         0.679   0.242    7   -15.781     0
# Everything Matters                 0.453   0.325    7    -9.758     0
#
#                             speechiness  acousticness  instrumentalness  \
# Do I Wanna Know (8D Audio)       0.0538         0.622          0.000023
# Everything Matters               0.0484         0.657          0.000065
#
#                             liveness  valence    tempo            type  \
# Do I Wanna Know (8D Audio)    0.1040    0.315   92.044  audio_features
# Everything Matters            0.0697    0.324  160.380  audio_features
#
#                                                 id  \
# Do I Wanna Know (8D Audio)  6dvGAhdmKhA4XTXkmo588g
# Everything Matters          1rMlnD8S0hX7IHZXZDt3gH
#
#                                                              uri  \
# Do I Wanna Know (8D Audio)  spotify:track:6dvGAhdmKhA4XTXkmo588g
# Everything Matters          spotify:track:1rMlnD8S0hX7IHZXZDt3gH
#
#                                                                    track_href  \
# Do I Wanna Know (8D Audio)  https://api.spotify.com/v1/tracks/6dvGAhdmKhA4...
# Everything Matters          https://api.spotify.com/v1/tracks/1rMlnD8S0hX7...
#
#                                                                  analysis_url  \
# Do I Wanna Know (8D Audio)  https://api.spotify.com/v1/audio-analysis/6dvG...
# Everything Matters          https://api.spotify.com/v1/audio-analysis/1rMl...
#
#                             duration_ms  time_signature
# Do I Wanna Know (8D Audio)       203983               4
# Everything Matters               213907               3

# %%
top20_df = top20_df[["id","acousticness","danceability","duration_ms","energy","instrumentalness","key","liveness","loudness","mode","speechiness","tempo","valence"]]
top20_df.head(n =2)
# Out:
#                                                 id  acousticness  \
# Do I Wanna Know (8D Audio)  6dvGAhdmKhA4XTXkmo588g         0.622
# Everything Matters          1rMlnD8S0hX7IHZXZDt3gH         0.657
#
#                             danceability  duration_ms  energy  \
# Do I Wanna Know (8D Audio)         0.679       203983   0.242
# Everything Matters                 0.453       213907   0.325
#
#                             instrumentalness  key  liveness  loudness  mode  \
# Do I Wanna Know (8D Audio)          0.000023    7    0.1040   -15.781     0
# Everything Matters                  0.000065    7    0.0697    -9.758     0
#
#                             speechiness    tempo  valence
# Do I Wanna Know (8D Audio)       0.0538   92.044    0.315
# Everything Matters               0.0484  160.380    0.324

# %% [markdown]
# ## 2. Organización de la información
# ### Listado de canciones candidatas
# Ahora, a partir del Top 20 canciones más escuchadas vamos a generar un *listado de canciones candidatas*, para esto haremos uso de la API para poder obtener artistas similares, los pasos a seguir serán:
# 1. Tomar los artistas sin repeticiones del Top 20.
# 2. Crear la lista de *Artistas relacionados* usando la API
#     a. ```sp.artist_related_artists```
#     b. ```sp.new_releases```
# 3. Crear la lista de *Albums* a partir de los artistas del paso anterior
# 4. Seleccionar canciones por cada *Album* del paso anterior

# %%
# Re-establecer conexión
sp = spotipy.Spotify(auth=token)

# %%
# 1. Extraer los artistas correspondientes al top 20 (sin repeticiones)
ids_artists = []
print('Artistas en mi top20:')
print('=====================')
for item in top20['items']:
    artist_id = item['artists'][0]['id']
    artist_name = item['artists'][0]['name']
    print(f'{artist_id}: {artist_name}')
    ids_artists.append(artist_id)
    
# Eliminar repetidos
ids_artists = list(set(ids_artists))
print(f'Número de artistas (sin repeticiones): {len(ids_artists)}')
# Out:
# Artistas en mi top20:
# =====================
# 2uSVRVjYZ0PlJPdFHnBETu: creamy
# 1WgXqy2Dd70QQOU7Ay074N: AURORA
# 1He0ZKninbT4FMEV9hUZKn: Mindchatter
# 2qk9voo8llSGYcZ6xrBzKx: Kings of Leon
# 0L8ExT028jH3ddEcZwqJJ5: Red Hot Chili Peppers
# 1bq8rqNnfrojn0OSAfeNXJ: Sarcastic Sounds
# 5KBPxIED8ejHkvhs4KCzyS: Granuja
# 5eAWCfyUhZtHHtBdNk56l1: System Of A Down
# 5g03v1dieHbVUP47XeXk7H: La Etnnia
# 7jy3rLJdDQY21OgRLCZ9sD: Foo Fighters
# 5KBPxIED8ejHkvhs4KCzyS: Granuja
# 4PLGokgPkAapRsKDwXq408: Doble Porcion
# 2EXpthNgSeTDeX8nGwxppp: Paris Paloma
# 5KBPxIED8ejHkvhs4KCzyS: Granuja
# 6XyY86QOPPrYVGvF9ch6wz: Linkin Park
# 5KBPxIED8ejHkvhs4KCzyS: Granuja
# 5KBPxIED8ejHkvhs4KCzyS: Granuja
# 5kROocD0ED0BYdVo7tJrSe: Tres Coronas
# 6olE6TJLqED3rqDCT0FyPh: Nirvana
# 0NcNqG01boinOKgb7ImmEJ: Vic Deal
# Número de artistas (sin repeticiones): 16

# %%
# 2. a. Crear lista de artistas relacionados usando la API
print('Artistas similares:')
print('=====================')
ids_similar_artists = []
for artist_id in ids_artists:
    artists = sp.artist_related_artists(artist_id)['artists']
    for item in artists:
        artist_id = item['id']    # Extraer ID de artista relacionado
        artist_name = item['name'] # Extraer nombre de artista relacionado
        print(f'{artist_id}: {artist_name}')
        ids_similar_artists.append(artist_id) # Agregar a la lista el artista relacionado
        
# Agregar artistas del top 20 a la lista de artistas candidatos
ids_artists.extend(ids_similar_artists)
# Eliminar repetidos
ids_artists = list(set(ids_artists))
print(f'Número de artistas (sin repeticiones): {len(ids_artists)}')
# Out:
# Artistas similares:
# =====================
# 31mtcsgS3CJW5dEPlG83E7: untrusted
# 42tsiNwD1xyyE4Hws2RvrC: Jasper
# 2MDj296KJIfgWDNBtHzeFi: 11:11 Music Group
# 1U0VLqR5nhfKiS3ngoqeZm: daddy's girl
# 6U65hm7m0hVAVGV0SXNFMw: ghostly echoes
# 5ac82nrmEXLxYO5Aa88aH7: Jess Taggart
# 6NYAOYclXxCr9rkMK8T8de: 8D sped up viral audios
# 4bGPjihFEUsxf9LPn1epOv: Martin Arteta
# 2v3eLcVAnCd6Yjeu0TzeGS: Hloshit
# 33FWu1JTA73HpPE2tBiwNX: Addict.
# 62AlnDIQccDoQ5FPZRrSL3: Solace
# 6YnaF6icmmm03VSrrM28ft: boy in skirt
# 59yO7tLFDTBR217x4u8iJn: pretence
# 1mVFtRG3DGigjQYeET4aJx: Yehu
# 1z0Ka2bQ4pcy89QzXw8dUa: sped up tiktok audios
# 2h36lqLlhIyJt4UpCJrLG5: meynus
# 1UkHuDUhU5Ik4cNH6F4XUq: Raspo
# 3O7oOXK7KPniAPEUorctsi: Sarah Meow
# 1N8Y4kaIF0ktxmylgsvUiY: Rewind
# 0K3Jtj8PRdPfgYLua8X1dv: Yusei
# 3ygJTpJJIK7eEeC2EFRl9D: Alcolirykoz
# 0cRHRB8jrBv74aDfyXQPrd: Rap Bang Club
# 6nfNQvqechLUJaFHYAciep: Aerophon
# 6i28S1MHCSNJtufoq0DnPv: No Rules Clan
# 3fQP5a7SIC91kV4N8AOy53: Crudo Means Raw
# 6oqagavQDMpR3KKeX4eqjL: N. Hardem
# 6kfPkheKpxesJXLqA4h7jO: Tsh Sudaca
# 7zXRgSpjJkQmB9SnPLq1Qk: Crack Family
# 1mVVNTPZrLkxfnB7Wc1Xh1: Anyone/Cualkiera
# 78rkeQAvjl85yNyLAqEMVe: Mañas Ru-Fino
# 1xS8E28QGLkEoXlJdY94hq: Sr Pablo
# 10MeG72hSqEKGbUdBowf9k: Métricas Frías
# 5Ti7e3WlCPPlcsZfxqtzTo: Ruzto
# 2XNJ1dXD5AjaHZTSM7qPlH: Margarita Siempre Viva
# 0NcNqG01boinOKgb7ImmEJ: Vic Deal
# 30IozP2GkHKFl6U59F86lF: Frank Takuma
# 02zSCw0p861wNWUjuC2jc3: Zof Ziro
# 5KBPxIED8ejHkvhs4KCzyS: Granuja
# 05aVtfDzBvg9eVu9MAZPGD: Cráneo
# 7zXRgSpjJkQmB9SnPLq1Qk: Crack Family
# 6nfNQvqechLUJaFHYAciep: Aerophon
# 38N7geKwv6xd2fESw199BD: Gordo Sarkasmus
# 78rkeQAvjl85yNyLAqEMVe: Mañas Ru-Fino
# 6i28S1MHCSNJtufoq0DnPv: No Rules Clan
# 1xS8E28QGLkEoXlJdY94hq: Sr Pablo
# 4mSxhskrhEcz1mZNVf1GWa: Kiño
# 3fQP5a7SIC91kV4N8AOy53: Crudo Means Raw
# 1mVVNTPZrLkxfnB7Wc1Xh1: Anyone/Cualkiera
# 0NcNqG01boinOKgb7ImmEJ: Vic Deal
# 6oqagavQDMpR3KKeX4eqjL: N. Hardem
# 5wDzgzMoyxqX2JC5WEskE6: Frank Jhonson
# 6ppLSXJZysRO3LBrlJIVuA: Soul AM
# 10MeG72hSqEKGbUdBowf9k: Métricas Frías
# 5mObIHCS5jSl4nbRnPAHGo: Original Juan
# 3ygJTpJJIK7eEeC2EFRl9D: Alcolirykoz
# 4otKDQdMIMEKTdZhh4ihql: Cejaz Negraz
# 5g03v1dieHbVUP47XeXk7H: La Etnnia
# 19Xm04ZiVtOB6J2Ti5vXhL: Arianna Puello
# 6p2PJ26AMGwS8ltwUjLfTR: JHT
# 2HiFszpmRqt7qy3eGBI62V: Nach Scratch
# 6KQCWkI62dV5ggZJpZKmJF: Asilo 38
# 3FgR6lfwIY7VD2lDryeh1e: Mexicano 777
# 3XQ1kcHi8muZSyZDoM3PmE: Gotas de Rap
# 2wyqtz49HtkuKDQIIFJCpM: Todo Copas
# 0v0zkNIz6CiaD0gubLmxYF: Askoman
# 6xg2jiUzovWjKI4CqXTqoQ: Alfonso Medina
# 7HYiFaf8421jcAZtEHIuv2: Flaco Flow y Melanina
# 1KJQ4evG4cqdICeqjdaIMn: Clan Hueso Duro
# 5Ef6JG1cW8s30S48REBgTa: Arma Blanca
# 5CWbuG3QC8Y2BFwBSdmKIQ: Superanfor
# 1Cd5Kq0yfp0WqfiryLu4bu: Laberinto ELC
# 4otKDQdMIMEKTdZhh4ihql: Cejaz Negraz
# 66ArjpKRgw8vYBf9yhktto: Nach
# 6nfNQvqechLUJaFHYAciep: Aerophon
# 1ltK3b65ZE7WKb7fGtufsj: Yoky Barrios
# 4mSxhskrhEcz1mZNVf1GWa: Kiño
# Número de artistas (sin repeticiones): 246

# %%
# 2. b. Crear listas de artistas con nuevos lanzamientos usando la API
print('')
print('Artistas con nuevos lanzamientos:')
print('=====================')
new_releases = sp.new_releases(limit=20)['albums'] # Llamando los nuevos lanzamientos a partir del objeto
for item in new_releases['items']:
    artist_id = item['artists'][0]['id']   #[0] porque puede haber varios artistas, se tomará el primero
    artist_name = item['artists'][0]['name']
    album_name = item['name']   # Nombre del album, puramente informativo
    release_date = item['release_date'] # Fecha de lanzamiento, puramente informativo
    print(f'{artist_id}: {artist_name} - // {album_name}, {release_date}')
    ids_artists.append(artist_id)
    
# Eliminar repetidos
ids_artists = list(set(ids_artists))
print(f'Número de artistas (sin repeticiones): {len(ids_artists)}')
# Out:
# Artistas con nuevos lanzamientos:
# =====================
# 2PfyKA4qhjkxUVkerTCxz0: Juan Pablo Vega - // Despídeme De Todxs, 2023-05-11
# 7gOdHgIoIKoe4i9Tta6qdD: Jonas Brothers - // The Album, 2023-05-12
# 6dexNK5MjEL8UvmA5MjSgg: Felipe Peláez - // Un Sueño Llamado RANCHERA, 2023-05-12
# 4tZwfgrHOc3mvqYlEYSvVi: Daft Punk - // Random Access Memories (10th Anniversary Edition), 2023-05-12
# 6eUKZXaKkcviH0Ku9w2n3V: Ed Sheeran - // - (Deluxe), 2023-05-05
# 0sXJRmgbjbq6Q5uu4W1wDM: Las Villa - // Eclipse, 2023-05-04
# 50sIhX3HytFEwQXZJLUZQE: Alejo - // EL FAVORITO DE LAS NENAS, 2023-05-04
# 1phfTBIocBW3UwqcYjaEN6: Mike Bahía - // Contigo, 2023-04-27
# 36KsCCwgI0Dep97yVJWmkK: Monsieur Periné - // Bolero Apocalíptico, 2023-04-27
# 22p8vOZwMABvl5qt2nZHWD: Vale - // A Contraluz, 2023-04-28
# 4vhNDa5ycK0ST968ek7kRr: Carlos Vives - // Escalona Nunca Se Había Grabado Así, 2023-04-18
# 68LgpWsaAwjflP3CLXC0LB: Susana Cala - // Sin Mensaje De Buenos Días, 2023-04-20
# 2o5jDhtHVPhrJdv3cEQ99Z: Tiësto - // DRIVE, 2023-04-21
# 2ye2Wgw4gimLv2eAKyk1NB: Metallica - // 72 Seasons, 2023-04-14
# 1cUpGtXcSQsovNYEZOQgOG: Nanpa Básico - // 99,9, 2023-04-12
# 6vwr6V7RwcWMDqVNerpNlZ: Delfina Dib - // Directo al Cora, 2023-04-14
# 1hLiboQ98IQWhpKeP9vRFw: boygenius - // the record, 2023-03-31
# 0SfsnGyD8FpIN4U4WCkBZ5: Armin van Buuren - // Feel Again, 2023-03-30
# 7ltDVBr6mKbRvohxheJ9h1: ROSALÍA - // RR, 2023-03-24
# 7iK8PXO48WeuP03g8YR51W: Myke Towers - // LA VIDA ES UNA, 2023-03-23
# Número de artistas (sin repeticiones): 266

# %% [markdown]
# Vamos a crear la lista de albums, para esto vamos a ir a obtener el nombre de cada album de cada artista, y es esos respectivos albums buscar canciones similares a las del Top 20, eso sería lo ideal, pero por ahora, vamos a trabajar con un album.

# %%
# 3. Crear la lista de albums 
id_albums = []
nartists = len(ids_artists)
for i, id_artist in enumerate(ids_artists):
    print(f'Procesando artista {i+1} de {nartists}...')
    albums = sp.artist_albums(id_artist, limit=1) # Nos limita a un Album por artista
    for album in albums['items']:
        id_albums.append(album['id'])
print('¡Listo!')
# Out:
# Procesando artista 1 de 266...
# Procesando artista 2 de 266...
# Procesando artista 3 de 266...
# Procesando artista 4 de 266...
# Procesando artista 5 de 266...
# Procesando artista 6 de 266...
# Procesando artista 7 de 266...
# Procesando artista 211 de 266...
# Procesando artista 212 de 266...
# Procesando artista 213 de 266...
# Procesando artista 214 de 266...
# Procesando artista 215 de 266...
# Procesando artista 216 de 266...
# Procesando artista 217 de 266...
# Procesando artista 218 de 266...
# Procesando artista 219 de 266...
# Procesando artista 220 de 266...
# Procesando artista 221 de 266...
# Procesando artista 222 de 266...
# Procesando artista 223 de 266...
# Procesando artista 224 de 266...
# Procesando artista 225 de 266...
# Procesando artista 226 de 266...
# Procesando artista 227 de 266...
# Procesando artista 228 de 266...
# Procesando artista 229 de 266...
# Procesando artista 230 de 266...
# Procesando artista 231 de 266...
# Procesando artista 232 de 266...
# Procesando artista 233 de 266...
# Procesando artista 234 de 266...
# Procesando artista 235 de 266...
# Procesando artista 236 de 266...
# Procesando artista 237 de 266...
# Procesando artista 238 de 266...
# Procesando artista 239 de 266...
# Procesando artista 240 de 266...
# Procesando artista 241 de 266...
# Procesando artista 242 de 266...
# Procesando artista 243 de 266...
# Procesando artista 244 de 266...
# Procesando artista 245 de 266...
# Procesando artista 246 de 266...
# Procesando artista 247 de 266...
# Procesando artista 248 de 266...
# Procesando artista 249 de 266...
# Procesando artista 250 de 266...
# Procesando artista 251 de 266...
# Procesando artista 252 de 266...
# Procesando artista 253 de 266...
# Procesando artista 254 de 266...
# Procesando artista 255 de 266...
# Procesando artista 256 de 266...
# Procesando artista 257 de 266...
# Procesando artista 258 de 266...
# Procesando artista 259 de 266...
# Procesando artista 260 de 266...
# Procesando artista 261 de 266...
# Procesando artista 262 de 266...
# Procesando artista 263 de 266...
# Procesando artista 264 de 266...
# Procesando artista 265 de 266...
# Procesando artista 266 de 266...
# ¡Listo!

# %% [markdown]
# > No recomendado para pruebas, solo para versión final
# Ahora, trabajaremos con más albums por artista, sin embargo, sin mostrar el proceso. **(Proceso demorado)**

# %%
# OMISIBLE SI SE ESTA PROBANDO
# id_albums = []
# nartists = len(ids_artists)
# for i, id_artist in enumerate(ids_artists):
#    albums = sp.artist_albums(id_artist, limit=3) # Ahora elegiremos 3 albums por artista
#    for album in albums['items']:
#        id_albums.append(album['id'])
# print('¡Listo!')

# %%
id_albums[0:5] # Recordar que estamos trabajando con IDs
# Out:
# ['2N2D3TzH9vw0kUu4UOpezT',
#  '2IEBtMYrYwqGfLXYPTSAHn',
#  '4RzfSdFKOqFP5HAzYOYxy3',
#  '7aTpmoysIfl5vhgAOJ0mp5',
#  '5puvjdeWFxlB0P1222trxX']

# %% [markdown]
# Vamos a extraer por cada album, 3 canciones, esto con el fin de qué el procesamiento no sea tan duro.

# %%
# 4. 
id_tracks = []
nalbums = len(id_albums)
for i, id_album in enumerate(id_albums):
    album_tracks = sp.album_tracks(id_album, limit=3) # NUMERO DE CANCIONES POR ALBUM
    for track in album_tracks['items']:
        id_tracks.append(track['id'])
print(f'¡Listo! Número total de canciones pre-candidatos: {len(id_tracks)}')
# Out:
# ¡Listo! Número total de canciones pre-candidatos: 765

# %% [markdown]
# Procesando track 740 de 765...
# Procesando track 741 de 765...
# Procesando track 742 de 765...
# Procesando track 743 de 765...
# Procesando track 744 de 765...
# Procesando track 745 de 765...
# Procesando track 746 de 765...
# Procesando track 747 de 765...
# Procesando track 748 de 765...
# Procesando track 749 de 765...
# Procesando track 750 de 765...
# Procesando track 751 de 765...
# Procesando track 752 de 765...
# Procesando track 753 de 765...
# Procesando track 754 de 765...
# Procesando track 755 de 765...
# Procesando track 756 de 765...
# Procesando track 757 de 765...
# Procesando track 758 de 765...
# Procesando track 759 de 765...
# Procesando track 760 de 765...
# Procesando track 761 de 765...
# Procesando track 762 de 765...
# Procesando track 763 de 765...
# Procesando track 764 de 765...
# Procesando track 765 de 765...
# ¡Listo!

# %%
candidatos_df.head()
# Out:
#                        danceability  energy  key  loudness  mode  speechiness  \
# Glistener                     0.450   0.879    6    -8.179     0       0.0651
# Cocoon                        0.294   0.829    5    -5.704     1       0.0419
# Blame                         0.558   0.940    9    -6.541     1       0.0479
# Eikthyrnir - Extended         0.167   0.322    6   -18.164     0       0.0357
# Ferden - Extended             0.281   0.426    0   -14.196     1       0.0298
#
#                        acousticness  instrumentalness  liveness  valence  \
# Glistener                    0.1950            0.3500    0.3810   0.3340
# Cocoon                       0.0128            0.0734    0.6130   0.3530
# Blame                        0.1240            0.5290    0.1640   0.3020
# Eikthyrnir - Extended        0.8990            0.9860    0.0845   0.0361
# Ferden - Extended            0.9020            0.9610    0.1150   0.2650
#
#                          tempo            type                      id  \
# Glistener              166.000  audio_features  73vM0ySuocYnuUbD1Arswt
# Cocoon                 130.103  audio_features  00RlGsJ1FxD5UfUwR52sBT
# Blame                  141.954  audio_features  61zGmSBNDo8KmTBgCCEogT
# Eikthyrnir - Extended   94.438  audio_features  1blu1jRkIWhpQGNLIweuco
# Ferden - Extended      137.878  audio_features  4pdtiVzTvQsaxZKiH4Bq9N
#
#                                                         uri  \
# Glistener              spotify:track:73vM0ySuocYnuUbD1Arswt
# Cocoon                 spotify:track:00RlGsJ1FxD5UfUwR52sBT
# Blame                  spotify:track:61zGmSBNDo8KmTBgCCEogT
# Eikthyrnir - Extended  spotify:track:1blu1jRkIWhpQGNLIweuco
# Ferden - Extended      spotify:track:4pdtiVzTvQsaxZKiH4Bq9N
#
#                                                               track_href  \
# Glistener              https://api.spotify.com/v1/tracks/73vM0ySuocYn...
# Cocoon                 https://api.spotify.com/v1/tracks/00RlGsJ1FxD5...
# Blame                  https://api.spotify.com/v1/tracks/61zGmSBNDo8K...
# Eikthyrnir - Extended  https://api.spotify.com/v1/tracks/1blu1jRkIWhp...
# Ferden - Extended      https://api.spotify.com/v1/tracks/4pdtiVzTvQsa...
#
#                                                             analysis_url  \
# Glistener              https://api.spotify.com/v1/audio-analysis/73vM...
# Cocoon                 https://api.spotify.com/v1/audio-analysis/00Rl...
# Blame                  https://api.spotify.com/v1/audio-analysis/61zG...
# Eikthyrnir - Extended  https://api.spotify.com/v1/audio-analysis/1blu...
# Ferden - Extended      https://api.spotify.com/v1/audio-analysis/4pdt...
#
#                        duration_ms  time_signature
# Glistener                   136757               4
# Cocoon                      247323               4
# Blame                       225877               4
# Eikthyrnir - Extended       196267               4
# Ferden - Extended           272187               3

# %%
# Reorganizar caracteristicas de las canciones para que queden igual al DataFrame del Top 20
candidatos_df = candidatos_df[["id","acousticness","danceability","duration_ms","energy","instrumentalness","key","liveness","loudness","mode","speechiness","tempo","valence"]]
candidatos_df.head(n =2)
# Out:
#                                id  acousticness  danceability  duration_ms  \
# Glistener  73vM0ySuocYnuUbD1Arswt        0.1950         0.450       136757
# Cocoon     00RlGsJ1FxD5UfUwR52sBT        0.0128         0.294       247323
#
#            energy  instrumentalness  key  liveness  loudness  mode  \
# Glistener   0.879            0.3500    6     0.381    -8.179     0
# Cocoon      0.829            0.0734    5     0.613    -5.704     1
#
#            speechiness    tempo  valence
# Glistener       0.0651  166.000    0.334
# Cocoon          0.0419  130.103    0.353

# %%
candidatos_df.shape

# %%
top20_df.shape
# Out:
# (20, 13)

# %%
top20_df.head()
# Out:
#                                                 id  acousticness  \
# Do I Wanna Know (8D Audio)  6dvGAhdmKhA4XTXkmo588g       0.62200
# Everything Matters          1rMlnD8S0hX7IHZXZDt3gH       0.65700
# Blame Game                  1WqgjwwlLRKE6qtcUY37S1       0.67300
# Sex on Fire                 0ntQJM78wzOLVeCUAW7Y45       0.00172
# Californication             48UPSzbZjgc449aqz8bxox       0.00210
#
#                             danceability  duration_ms  energy  \
# Do I Wanna Know (8D Audio)         0.679       203983   0.242
# Everything Matters                 0.453       213907   0.325
# Blame Game                         0.668       201255   0.592
# Sex on Fire                        0.542       203347   0.905
# Californication                    0.592       329733   0.767
#
#                             instrumentalness  key  liveness  loudness  mode  \
# Do I Wanna Know (8D Audio)          0.000023    7    0.1040   -15.781     0
# Everything Matters                  0.000065    7    0.0697    -9.758     0
# Blame Game                          0.756000    9    0.0880   -12.645     1
# Sex on Fire                         0.010400    9    0.1360    -5.653     1
# Californication                     0.001650    9    0.1270    -2.788     0
#
#                             speechiness    tempo  valence
# Do I Wanna Know (8D Audio)       0.0538   92.044    0.315
# Everything Matters               0.0484  160.380    0.324
# Blame Game                       0.1390  179.949    0.488
# Sex on Fire                      0.0540  153.398    0.374
# Californication                  0.0270   96.483    0.328

# %%
candidatos_df.head()

# %% [markdown]
# ## 3. Aplicación del modelo
# ### Preprocesamiento de los datos
# Para comenzar a elegir las canciones recomendadas, vamos a usar un *Sistema de recomendación basado en contenido*, lo cuál implica que compararemos las caracteristicas sonoras del Top 20 canciones del usuario con las **canciones candidatas** elegidas anteriormente.

# %%
# Tomar solo las caracteristicas de las canciones para poder así compararlas
top20_mtx = top20_df.iloc[:,1:].values
candidatos_mtx = candidatos_df.iloc[:,1:].values

# %% [markdown]
# Como estamos hablando de vectores de 13 dimensiones, donde cada una de sus componentes tiene su propia escala, lo primero que debemos hacer es estandarizarlas.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
t20_scaled = scaler.fit_transform(top20_mtx)
can_scaled = scaler.fit_transform(candidatos_mtx)

# %% [markdown]
# Ahora, tenemos vectores estandarizados, pero para poder comparlos entre ellos necesitamos normalizarlos, lo que haremos a continuación:

# %%
import numpy as np

# Raíz de la suma
t20_norm = np.sqrt((t20_scaled*t20_scaled).sum(axis=1))
can_norm = np.sqrt((can_scaled*can_scaled).sum(axis=1))
# División de la norma
nt20 = t20_scaled.shape[0]
ncan = can_scaled.shape[0]
t20 = t20_scaled/t20_norm.reshape(nt20,1)
can = can_scaled/can_norm.reshape(ncan,1)

# %% [markdown]
# El método sencillo pero efectivo usado frecuentemente en el Machine Learning es el de similitud de Coseno, donde al comparar dos vectores si se asemeja a 1 el coseno quiere decir que son similares, si se asemeja a 0 no tienen similaridad y si se asemejan a -1 son opuestos, usaremos este metodos para comparar ambos vectores.

# %%
from sklearn.metrics.pairwise import linear_kernel

cos_sim = linear_kernel(t20,can)
cos_sim.shape
# Out:
# (20, 764)

# %%
cos_sim
# Out:
# array([[-1.06708502e-01, -4.44030856e-01, -4.58429124e-01, ...,
#         -5.75917556e-01,  1.85887642e-01, -2.73185812e-04],
#        [ 3.92789396e-01, -4.50410303e-02, -1.47659677e-01, ...,
#         -4.07590837e-01, -1.32165501e-01,  4.63161561e-01],
#        [ 2.85765460e-01, -1.81117684e-01,  5.18239837e-01, ...,
#         -6.42316887e-02,  2.01381719e-01,  1.89503682e-01],
#        ...,
#        [-9.16672650e-02,  5.26162331e-01, -1.96121224e-01, ...,
#          1.69027568e-01, -4.44458089e-02, -1.08233714e-01],
#        [-4.03044748e-02,  6.88041156e-02,  1.32944919e-01, ...,
#         -6.50830725e-01,  2.40068784e-01,  1.28503136e-01],
#        [-2.51774774e-01, -4.96695759e-01, -3.95764000e-01, ...,
#          1.87926357e-01, -5.53972710e-02, -3.50845880e-01]])

# %% [markdown]
# Tenemos una matriz de 20 filas, es decir, el top 20 del usuario, y las comparamos con cada una de las canciones candidatas.  Ahora lo que tenemos que hacer es buscar las canciones que tengan más similitud con las canciones del top 20, para eso usaremos la siguiente función.

# %%
# Obtener candidatos para una canción
# pos -> posicion de la canción del top 20
# cos_sim -> la matriz de cosenos 
# n -> candidatos número de candidatos por canción del top 20
# umbral -> Nivel de similitud a la referencial 
def obtener_candidatos(pos, cos_sim, ncandidatos, umbral = 0.8):
    # Obtener todas las pistas candidatas por encima de umbral
    idx = np.where(cos_sim[pos,:]>=umbral)[0] # ejm. idx: [27, 82, 135]
    
    # Y organizarlas de forma descendente (por similitudes de mayor a menor)
    idx = idx[np.argsort(cos_sim[pos,idx])[::-1]] # [::-1] porque por defecto argsort organiza de manera ascendente

    # Si hay más de "ncandidatos", retornar máximo "ncandidatos"
    if len(idx) >= ncandidatos:
        candidatos = idx[0:ncandidatos]
    else:
        candidatos = idx
  
    return candidatos

# %%
# Prueba
for i in range(5):
    cands = obtener_candidatos(i, cos_sim, 5)
    print(f'{i}==> pistas filtradas: {cands}, similitudes: {cos_sim[i,cands]}')
# Out:
# 0==> pistas filtradas: [182  45 214 183 727], similitudes: [0.92590158 0.86290426 0.8525872  0.83470603 0.83116108]
# 1==> pistas filtradas: [517], similitudes: [0.83776351]
# 2==> pistas filtradas: [], similitudes: []
# 3==> pistas filtradas: [260 637 731 335 733], similitudes: [0.90355652 0.90221597 0.9021726  0.88812643 0.8752983 ]
# 4==> pistas filtradas: [520 175 526 330], similitudes: [0.90958809 0.88337997 0.82023109 0.81579706]

# %% [markdown]
# A continuación, guardaremos en una lista las pistas similares a las del top 20, imprimiendo además cuales canciones de los *artistas relacionados* y de los *nuevos lanzamientos* fueron seleccionadas por cada canción del Top 20.

# %%
ids_t20 = []
ids_playlist = []

for i in range(top20_df.shape[0]):
    print(f'{i+1}. {top20_df.index[i]}')   # Nombre de la pista en el top-20
    ids_t20.append(top20_df['id'][i])
    
    # Obtener listado de candidatos para esta pista
    cands = obtener_candidatos(i, cos_sim, 5, umbral=0.8)
    
    # Si hay pistas relacionadas obtener los ids correspondientes e imprimir en pantalla
    if len(cands)==0:
        print('     ***No se encontraron pistas relacionadas***')
    else:
        # Obtener los ids correspondientes e imprimir en pantalla
        for j in cands:
            id_cand = candidatos_df['id'][j]
            ids_playlist.append(id_cand)
            
            # E imprimir en pantalla el candidato
            print(f'   * {candidatos_df.index[j]}')
# Out:
# 1. Do I Wanna Know (8D Audio)
#    * Confined
#    * supermodel
#    * Exhale Inhale
#    * Monalogue
#    * I Kissed Someone (It Wasn't You)
# 2. Everything Matters
#    * Carrion Comfort - Slowed
# 3. Blame Game
#      ***No se encontraron pistas relacionadas***
# 4. Sex on Fire
#    * Attack
#    * Under You
#    * You Don't Know
#    * Machine (Ft. Gary Stringer)
#    * Go to Hell
# 5. Californication
#    * Screaming Suicide
#    * Heart Attack
#    * State Of The Art
#    * The One You Know
# 6. say goodbye
#    * Una Preguntita (Intro)
# 7. De Pe a Pa
#    * Hasta el Último Round
#    * Noche de Bohemia
#    * La Vida Es Corta
# 8. Toxicity
#    * Under You
#    * Machine (Ft. Gary Stringer)
#    * Take Me Out
#    * Slow Me
#    * Rescued
# 9. Noicanicula
#    * Walk
#    * Lilo & Stitch
#    * La Cosecha (Sascha Fitness)
# 10. The Pretender
#    * You Don't Know
#    * Go to Hell
#    * Under You
#    * Rescued
#    * Attack
# 11. Ateo
#    * Una Preguntita (Intro)
# 12. Roca N' Ron
#    * Derrapando
#    * Sguardi
# 13. It's Called: Freefall
#    * Más o Menos Antes
#    * It's a Little High All the Way Up Here
#    * Wait for Me
#    * Terrible Thing
#    * I Still Don't Know Who I Am.
# 14. Quién Pidió Pollo
#    * En Busca de la Felicidad
#    * Peace and Love
# 15. Faint
#    * Z28
#    * Gasoline
#    * Horror Show - 2022 Remaster
#    * Failure - Aurora Version
#    * So Called Life
# 16. Under Kings
#    * Aprovéchame
#    * NIKKI
# 17. Días de Perros
#    * Marionetas
#    * Caciques del Altiplano
#    * Pido permiso
# 18. Falsedades
#    * Start The Healing - Requiem Mass
#    * Not Again - Live
#    * Derrapando
#    * Cambiando el Mundo
# 19. Something In The Way
#    * Sanctuary
#    * Hue
#    * Picturesque
#    * you look like summer
#    * HYACINTHUS
# 20. El Emblema
#    * Tonos Grises
#    * Tonos Grises
#    * Faraón
#    * Caciques del Altiplano
#    * Rap Cum Laude

# %%
# Eliminar canciones recomendadas que ya hacen parte del Top 20 o están repetidas
ids_playlist_dep = [x for x in ids_playlist if x not in ids_t20]
ids_playlist_dep = list(set(ids_playlist_dep))

# %%
print('Canciones Recomendadas:')
print('=====================')
for item in ids_playlist_dep:
    track = sp.track(item)
    song_name = track['name']
    artist_name = track['artists'][0]['name']
    print(song_name, end=' - ')
    print(artist_name)
    
# Buscar la canción por su ID
#track = sp.track(song_id)

# Obtener el nombre del artista
#artist_name = track['artists'][0]['name']
# Out:
# Canciones Recomendadas:
# =====================
# Peace and Love - Red Hot Chili Peppers
# supermodel - untrusted
# Horror Show - 2022 Remaster - The Libertines
# Marionetas - La Etnnia
# The One You Know - Alice In Chains
# Pido permiso - Nach Scratch
# It's a Little High All the Way Up Here - Vian Izak
# Start The Healing - Requiem Mass - Korn
# La Cosecha (Sascha Fitness) - Soul AM
# Heart Attack - Editors
# Screaming Suicide - Metallica
# State Of The Art - Incubus
# Confined - Timmies
# Caciques del Altiplano - Ali Aka Mind
# La Vida Es Corta - Clan Hueso Duro
# Take Me Out - Franz Ferdinand
# Derrapando - Cráneo
# Gasoline - Seether
# You Don't Know - Puddle Of Mudd
# Under You - Foo Fighters
# Z28 - Static-X
# Not Again - Live - Staind
# Sguardi - Fedi
# Slow Me - Bush
# I Still Don't Know Who I Am. - Barnes Blvd.
# Go to Hell - Puddle Of Mudd
# Sanctuary - Attom
# Faraón - Cejaz Negraz
# HYACINTHUS - Aidoneus
# Una Preguntita (Intro) - Los Elefantes
# Lilo & Stitch - Soul AM
# I Kissed Someone (It Wasn't You) - dodie
# Walk - potsu
# Exhale Inhale - AURORA
# Carrion Comfort - Slowed - aeseaes
# Hasta el Último Round - Superanfor
# Failure - Aurora Version - Breaking Benjamin
# Rap Cum Laude - Vic Deal
# Hue - Attom
# Terrible Thing - The Killers
# Cambiando el Mundo - Arianna Puello
# Noche de Bohemia - Laberinto ELC
# Más o Menos Antes - Silvana Estrada
# Aprovéchame - Yoky Barrios
# Picturesque - Attom
# So Called Life - Three Days Grace
# Attack - System Of A Down
# NIKKI - Alejo
# Machine (Ft. Gary Stringer) - Skindred
# Monalogue - Timmies
# you look like summer - Askjell
# Rescued - Foo Fighters
# Tonos Grises - Métricas Frías
# En Busca de la Felicidad - Kiño
# Wait for Me - AlicebanD

# %% [markdown]
# ## 4. Evaluación del modelo
# Para la evaluación del modelo intentamos usar una métrica de precisión que ayudara a evaluar qué tan precisas y completas son las recomendaciones. Partiendo del hecho que usamos el top 20 como entrenamiento y las demás canciones escuchadas por el usario como prueba, y luego así calcular la precisión.
# La precisión se refiere a la proporción de recomendaciones relevantes entre todas las recomendaciones.
#
# Sin embargo, este metodo es aplicable cuando se tienen **_múltiples usuarios_**, y hacer comparaciones dentro de solo una playlist de recomendaciones no da mucho para concluir.
